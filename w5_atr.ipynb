# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm  # 进度条工具（可选）
from pathlib import Path
from datetime import datetime, timedelta
import re
import glob

# %%
# 数据加载与预处理
def load_and_preprocess_data(data_path):
    """
    加载所有CSV 通过文件名构建交易日历，创建正确的时间戳，并合并。
    """
    print("Scanning filenames to build trading calendar...")
    all_files = sorted(glob.glob(os.path.join(data_path, "*.csv")))
    
    # 从文件名中提取所有交易日，并去重排序
    trading_dates_str = sorted(list(set([os.path.basename(f).split('_')[1].split('.')[0] for f in all_files])))
    
    # 创建从一个交易日到其前一个交易日的映射字典
    prev_trading_date_map = {trading_dates_str[i]: trading_dates_str[i-1] for i in range(1, len(trading_dates_str))}
    
    df_list = []
    
    print("Processing each file with the new calendar logic...")
    for file_path in all_files:
        try:
            # 从文件名提取当前文件的交易日
            current_trading_date_str = os.path.basename(file_path).split('_')[1].split('.')[0]
            current_trading_date = pd.to_datetime(current_trading_date_str, format='%Y%m%d')
            
            # 查找前一个交易日
            prev_date_str = prev_trading_date_map.get(current_trading_date_str)
            if not prev_date_str:
                # 对于的第一个文件，假设其夜盘是前一个日历日 这种情况仅对数据集最开始的那个夜盘有影响。
                prev_calendar_date = current_trading_date - timedelta(days=1)
            else:
                prev_calendar_date = pd.to_datetime(prev_date_str, format='%Y%m%d')

            required_cols = ['InstrumentID', 'UpdateTime', 'UpdateMillisec', 'LastPrice'] 
            df = pd.read_csv(file_path, usecols = required_cols)
            df['date'] = current_trading_date_str
            print(f'{file_path} loaded...')

            # 创建真实时间戳
            def get_true_timestamp(row):
                time_part = pd.to_datetime(row['UpdateTime'], format='%H:%M:%S').time()
                
                # 夜盘的日历日期
                if time_part.hour >= 21:
                    calendar_date = prev_calendar_date
                # 日盘的日历日期
                else:
                    calendar_date = current_trading_date
                
                # 合并日期、时间和毫秒
                return pd.Timestamp(calendar_date.year, calendar_date.month, calendar_date.day,
                                    time_part.hour, time_part.minute, time_part.second) + \
                       pd.to_timedelta(row['UpdateMillisec'], unit='ms')

            df['Timestamp'] = df.apply(get_true_timestamp, axis=1)
            df_list.append(df)
            
        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
            
    # 合并所有数据并按时间戳排序
    full_df = pd.concat(df_list, ignore_index=True)
    full_df = full_df.sort_values('Timestamp').reset_index(drop=True)
    
    return full_df


# --- 其他函数保持不变 ---

def filter_by_trading_hours(df):
    """
    只考虑连续竞价
    """
    df['Time'] = df['Timestamp'].dt.time
    
    # 定义交易时间段
    night_session = (df['Time'] >= pd.to_datetime('21:00:00').time()) & \
                    (df['Time'] <= pd.to_datetime('23:00:00').time())
    
    morning_session_1 = (df['Time'] >= pd.to_datetime('09:00:00').time()) & \
                        (df['Time'] <= pd.to_datetime('10:15:00').time())
    
    morning_session_2 = (df['Time'] >= pd.to_datetime('10:30:00').time()) & \
                        (df['Time'] <= pd.to_datetime('11:30:00').time())
                        
    afternoon_session = (df['Time'] >= pd.to_datetime('13:30:00').time()) & \
                        (df['Time'] <= pd.to_datetime('15:00:00').time())
                        
    # 过滤
    valid_time_mask =  morning_session_1 | morning_session_2 | afternoon_session
    
    return df[valid_time_mask].drop(columns=['Time']).copy()

def generate_5min_klines(df):
    """
    从tick数据生成固定切割的5分钟OHLC K线。如 09:00~09:05, 09:05~09:10等
    """
    klines_5min = df.set_index('Timestamp')['LastPrice'].resample('5min').agg(
        Open='first',
        High='max',
        Low='min',
        Close='last'
    ).dropna() # 出现缺失值意味着非交易时间的K线 直接删除
    
    return klines_5min

def calculate_tick_atr(df, klines_5min):
    """
    计算每条tick对应的ATR。
    """
    print("Preparing historical K-line data for ATR calculation...")
    klines_5min_shifted = klines_5min.copy()
    for i in range(1, 13):
        klines_5min_shifted[f'High_p{i}'] = klines_5min['High'].shift(i)
        klines_5min_shifted[f'Low_p{i}'] = klines_5min['Low'].shift(i)
        klines_5min_shifted[f'Close_p{i}'] = klines_5min['Close'].shift(i)
        
    df['kline_timestamp'] = df['Timestamp'].dt.floor('5T')
    df = pd.merge(df, klines_5min_shifted, left_on='kline_timestamp', right_index=True, ) # how='left'

    print("Calculating values for the current K-line...")
    df['Current_K_High'] = df.groupby('kline_timestamp')['LastPrice'].cummax()
    df['Current_K_Low'] = df.groupby('kline_timestamp')['LastPrice'].cummin()
    
    print("Calculating 12 True Ranges (TR)...")
    tr_cols = []
    
    # TR_1
    true_range_1_h_l = df['Current_K_High'] - df['Current_K_Low']
    true_range_1_h_pc = (df['Current_K_High'] - df['Close_p1']).abs()
    true_range_1_l_pc = (df['Current_K_Low'] - df['Close_p1']).abs()
    df['TR_1'] = np.maximum.reduce([true_range_1_h_l, true_range_1_h_pc, true_range_1_l_pc])
    tr_cols.append('TR_1')

    # TR_2 to TR_12
    for i in range(2, 13):
        prev_k_high = df[f'High_p{i-1}']
        prev_k_low = df[f'Low_p{i-1}']
        prev_k_close = df[f'Close_p{i}']
        tr_h_l = prev_k_high - prev_k_low
        tr_h_pc = (prev_k_high - prev_k_close).abs()
        tr_l_pc = (prev_k_low - prev_k_close).abs()
        df[f'TR_{i}'] = np.maximum.reduce([tr_h_l, tr_h_pc, tr_l_pc])
        tr_cols.append(f'TR_{i}')

    print("Calculating final ATR...")
    df['ATR'] = df[tr_cols].mean(axis=1,skipna=False)

    final_cols = ['date', 'UpdateTime', 'UpdateMillisec','Timestamp', 'kline_timestamp', 'InstrumentID','LastPrice', 'ATR']
    final_df = df[final_cols].dropna(subset=['ATR'])
    
    return final_df

# 生成交易时间列表（间隔1秒）
def generate_trading_hours():
    morning_start = datetime.strptime("09:00:00", "%H:%M:%S").time()
    morning_end = datetime.strptime("11:30:00", "%H:%M:%S").time()
    afternoon_start = datetime.strptime("13:30:00", "%H:%M:%S").time()
    afternoon_end = datetime.strptime("14:59:59", "%H:%M:%S").time()
    
    time_list = []
    current_time = morning_start
    while current_time <= morning_end:
        time_list.append(current_time.strftime("%H:%M:%S"))
        current_time = (datetime.combine(datetime.min, current_time) + 
                       timedelta(seconds=1)).time()
    
    current_time = afternoon_start
    while current_time <= afternoon_end:
        time_list.append(current_time.strftime("%H:%M:%S"))
        current_time = (datetime.combine(datetime.min, current_time) + 
                       timedelta(seconds=1)).time()
    
    return time_list

def process_trading_day_ticks(df, time_univ, session_mark):
    
    # 提取交易日
    market_df = df.copy()

    market_df['UpdateMillisec'] = market_df['UpdateMillisec'].astype(int)

    template_df = pd.DataFrame({
        'UpdateTime': time_univ,
        'UpdateMillisec': 0  # 为我们的切片时间戳设置毫秒为0
    })

    combined_df = pd.concat([market_df, template_df], ignore_index=True)

    combined_df['session_part'] = (combined_df['UpdateTime'].str[:2].astype(int) < session_mark).astype(int)

    combined_df.sort_values(
        by=['session_part', 'UpdateTime', 'UpdateMillisec'], 
        inplace=True,
        kind='mergesort'
    )
    combined_df = combined_df.ffill()

    result_df = combined_df[combined_df['UpdateTime'].isin(time_univ) & (combined_df['UpdateMillisec'] == 0)]
    
    # 删除可能的重复项（如果一个秒正好有0毫秒的tick，排序之后切片行会出现在原始数据行之后, 此时保留最后一条是合理的）
    result_df.drop_duplicates(subset=['UpdateTime'], keep='last', inplace=True)
    
    new_order = [
       'date', 'InstrumentID', 'UpdateTime', 'session_part', 'LastPrice', 'ATR'
    ]
    result_df = result_df[new_order].dropna(subset=['InstrumentID']).reset_index(drop=True) # dropna是为了处理那些没有夜盘的交易日或者没有夜盘的品种

    return result_df.rename(columns={"date": "trading_date","UpdateTime": "ts"})

# %%
if __name__ == '__main__':
    comd_list = ['lc']
    for comd in comd_list:
        DATA_DIRECTORY = f"C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/{comd}"
        
        # 1. 加载和预处理
        tick_df = load_and_preprocess_data(DATA_DIRECTORY)
        print(f"Loaded {len(tick_df)} total ticks.")
        #tick_df.to_parquet('/data/datas/zhangyy/6100T/tick_2025_p.parquet')
        
        # 2. 过滤交易时间
        tick_df_filtered = filter_by_trading_hours(tick_df)
        print(f"Found {len(tick_df_filtered)} ticks within trading hours.")
        final_atr_df = []
        for _, df in tick_df_filtered.groupby('InstrumentID'): # 主力换月时分开计算
            final_atr_temp = calculate_tick_atr(df, generate_5min_klines(df))
            final_atr_df.append(final_atr_temp)
        df_atr = pd.concat(final_atr_df, axis=0)
        #print(df_atr)#.to_parquet('/data/datas/zhangyy/6100T/p.atr.parquet')

        # 3. 转化成秒级数据
        '''
        df_atr = df_atr.loc[df_atr.groupby(['UpdateTime', 'date'])['UpdateMillisec'].idxmin()]
        df_atr.sort_values(by=['Timestamp'], inplace=True)
        df_atr.reset_index(drop=True, inplace=True)
        print(df_atr)
        '''
        pd.options.mode.copy_on_write = True 
        DCE_TIME_UNIV = generate_trading_hours()
        final_atr_df = df_atr

        result = []
        for _, df in final_atr_df.groupby('date'):
            single_date = process_trading_day_ticks(df, DCE_TIME_UNIV, 20)
            print(single_date)
            result.append(single_date)
        result = pd.concat(result, axis=0)
        result.reset_index(inplace=True,drop=True)
        print(result)
        #result.to_parquet('C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/processed/{comd}_atr_1s_.parquet')
# Out:
# Scanning filenames to build trading calendar...
# Processing each file with the new calendar logic...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230721.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230724.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230725.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230726.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230727.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230728.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230731.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230801.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230802.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230803.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230804.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230807.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230808.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230809.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230810.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230811.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230814.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230815.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230816.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230817.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230818.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230821.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230822.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230823.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230824.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230825.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230828.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230829.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230830.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230831.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230901.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230904.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230905.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230906.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230907.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230908.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230911.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230912.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230913.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230914.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230915.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230918.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230919.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230920.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230921.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230922.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230925.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230926.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230927.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20230928.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231009.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231010.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231011.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231012.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231013.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231016.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231017.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231018.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231019.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231020.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231023.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231024.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231025.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231026.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231027.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231030.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231031.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231101.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231102.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231103.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231106.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231107.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231108.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231109.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231110.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231113.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231114.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231115.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231116.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231117.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231120.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231121.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231122.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231123.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231124.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231127.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231128.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231129.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231130.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231201.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231204.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231205.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231206.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231207.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231208.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231211.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231212.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231213.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231214.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231215.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231218.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231219.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231220.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231221.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231222.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231225.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231226.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231227.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231228.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20231229.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240102.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240103.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240104.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240105.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240108.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240109.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240110.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240111.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240112.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240115.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240116.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240117.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240118.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240119.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240122.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240123.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240124.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240125.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240126.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240129.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240130.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240131.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240201.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240202.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240205.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240206.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240207.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240208.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240219.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240220.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240221.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240222.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240223.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240226.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240227.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240228.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240229.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240301.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240304.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240305.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240306.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240307.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240308.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240311.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240312.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240313.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240314.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240315.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240318.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240319.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240320.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240321.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240322.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240325.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240326.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240327.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240328.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240329.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240401.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240402.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240403.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240408.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240409.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240410.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240411.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240412.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240415.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240416.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240417.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240418.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240419.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240422.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240423.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240424.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240425.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240426.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240429.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240430.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240506.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240507.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240508.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240509.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240510.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240513.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240514.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240515.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240516.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240517.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240520.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240521.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240522.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240523.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240524.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240527.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240528.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240529.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240530.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240531.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240603.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240604.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240605.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240606.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240607.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240611.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240612.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240613.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240614.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240617.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240618.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240619.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240620.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240621.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240624.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240625.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240626.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240627.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240628.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240701.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240702.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240703.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240704.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240705.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240708.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240709.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240710.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240711.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240712.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240715.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240716.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240717.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240718.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240719.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240722.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240723.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240724.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240725.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240726.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240729.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240730.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240731.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240801.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240802.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240805.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240806.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240807.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240808.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240809.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240812.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240813.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240814.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240815.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240816.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240819.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240820.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240821.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240822.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240823.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240826.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240827.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240828.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240829.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240830.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240902.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240903.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240904.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240905.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240906.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240909.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240910.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240911.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240912.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240913.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240918.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240919.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240920.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240923.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240924.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240925.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240926.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240927.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20240930.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241008.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241009.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241010.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241011.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241014.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241015.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241016.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241017.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241018.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241021.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241022.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241023.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241024.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241025.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241028.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241029.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241030.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241031.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241101.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241104.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241105.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241106.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241107.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241108.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241111.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241112.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241113.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241114.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241115.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241118.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241119.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241120.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241121.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241122.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241125.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241126.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241127.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241128.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241129.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241202.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241203.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241204.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241205.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241206.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241209.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241210.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241211.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241212.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241213.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241216.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241217.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241218.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241219.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241220.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241223.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241224.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241225.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241226.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241227.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241230.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20241231.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250102.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250103.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250106.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250107.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250108.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250109.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250110.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250113.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250114.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250115.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250116.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250117.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250120.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250121.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250122.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250123.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250124.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250127.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250205.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250206.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250207.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250210.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250211.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250212.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250213.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250214.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250217.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250218.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250219.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250220.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250221.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250224.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250225.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250226.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250227.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250228.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250303.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250304.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250305.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250306.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250307.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250310.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250311.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250312.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250313.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250314.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250317.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250318.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250319.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250320.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250321.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250324.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250325.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250326.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250327.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250328.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250331.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250401.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250402.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250403.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250407.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250408.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250409.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250410.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250411.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250414.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250415.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250416.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250417.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250418.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250421.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250422.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250423.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250424.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250425.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250428.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250429.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250430.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250506.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250507.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250508.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250509.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250512.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250513.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250514.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250515.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250516.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250519.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250520.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250521.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250522.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250523.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250526.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250527.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250528.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250529.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250530.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250603.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250604.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250605.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250606.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250609.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250610.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250611.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250612.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250613.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250616.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250617.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250618.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250619.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250620.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250623.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250624.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250625.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250626.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250627.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250630.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250701.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250702.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250703.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250704.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250707.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250708.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250709.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250710.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250711.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250714.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250715.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250716.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250717.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250718.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250721.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250722.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250723.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250724.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250725.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250728.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250729.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250730.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250731.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250801.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250804.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250805.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250806.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250807.csv loaded...
# C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/data/2023-2025/lc\sel_20250808.csv loaded...
# ...
# 0         20250728       lc2509  09:00:01             1    74140.0  765.000000
# 1         20250728       lc2509  09:00:02             1    73980.0  778.333333
# 2         20250728       lc2509  09:00:03             1    74240.0  778.333333
# 3         20250728       lc2509  09:00:04             1    74020.0  778.333333
# 4         20250728       lc2509  09:00:05             1    74200.0  778.333333
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250728       lc2509  14:59:55             1    73120.0    0.000000
# 14396     20250728       lc2509  14:59:56             1    73120.0    0.000000
# 14397     20250728       lc2509  14:59:57             1    73120.0    0.000000
# 14398     20250728       lc2509  14:59:58             1    73120.0    0.000000
# 14399     20250728       lc2509  14:59:59             1    73120.0    0.000000
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250729       lc2509  09:00:01             1    70880.0  186.666667
# 1         20250729       lc2509  09:00:02             1    71060.0  186.666667
# 2         20250729       lc2509  09:00:03             1    71460.0  186.666667
# 3         20250729       lc2509  09:00:04             1    71680.0  186.666667
# 4         20250729       lc2509  09:00:05             1    71260.0  186.666667
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250729       lc2509  14:59:55             1    70860.0  346.666667
# 14396     20250729       lc2509  14:59:56             1    70860.0  346.666667
# 14397     20250729       lc2509  14:59:57             1    70880.0  346.666667
# 14398     20250729       lc2509  14:59:58             1    70880.0  346.666667
# 14399     20250729       lc2509  14:59:59             1    70820.0  346.666667
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250730       lc2509  09:00:01             1    73100.0  508.333333
# 1         20250730       lc2509  09:00:02             1    73240.0  520.000000
# 2         20250730       lc2509  09:00:03             1    73120.0  520.000000
# 3         20250730       lc2509  09:00:04             1    73260.0  521.666667
# 4         20250730       lc2509  09:00:05             1    73240.0  528.333333
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250730       lc2509  14:59:55             1    70660.0  650.000000
# 14396     20250730       lc2509  14:59:56             1    70640.0  650.000000
# 14397     20250730       lc2509  14:59:57             1    70640.0  650.000000
# 14398     20250730       lc2509  14:59:58             1    70640.0  650.000000
# 14399     20250730       lc2509  14:59:59             1    70640.0  650.000000
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250731       lc2509  09:00:01             1    68740.0  746.666667
# 1         20250731       lc2509  09:00:02             1    68700.0  750.000000
# 2         20250731       lc2509  09:00:03             1    68740.0  750.000000
# 3         20250731       lc2509  09:00:04             1    68820.0  750.000000
# 4         20250731       lc2509  09:00:05             1    68920.0  750.000000
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250731       lc2509  14:59:55             1    68260.0  591.666667
# 14396     20250731       lc2509  14:59:56             1    68260.0  591.666667
# 14397     20250731       lc2509  14:59:57             1    68300.0  591.666667
# 14398     20250731       lc2509  14:59:58             1    68280.0  591.666667
# 14399     20250731       lc2509  14:59:59             1    68300.0  591.666667
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250801       lc2509  09:00:01             1    69320.0  638.333333
# 1         20250801       lc2509  09:00:02             1    69120.0  638.333333
# 2         20250801       lc2509  09:00:03             1    69000.0  638.333333
# 3         20250801       lc2509  09:00:04             1    69020.0  638.333333
# 4         20250801       lc2509  09:00:05             1    69000.0  638.333333
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250801       lc2509  14:59:55             1    68940.0  375.000000
# 14396     20250801       lc2509  14:59:56             1    68920.0  375.000000
# 14397     20250801       lc2509  14:59:57             1    68880.0  375.000000
# 14398     20250801       lc2509  14:59:58             1    68880.0  375.000000
# 14399     20250801       lc2509  14:59:59             1    68940.0  375.000000
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250804       lc2509  09:00:01             1    69240.0  348.333333
# 1         20250804       lc2509  09:00:02             1    69280.0  351.666667
# 2         20250804       lc2509  09:00:03             1    69240.0  351.666667
# 3         20250804       lc2509  09:00:04             1    69260.0  351.666667
# 4         20250804       lc2509  09:00:05             1    69260.0  353.333333
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250804       lc2509  14:59:55             1    68940.0  263.333333
# 14396     20250804       lc2509  14:59:56             1    68940.0  263.333333
# 14397     20250804       lc2509  14:59:57             1    68940.0  263.333333
# 14398     20250804       lc2509  14:59:58             1    68920.0  263.333333
# 14399     20250804       lc2509  14:59:59             1    68900.0  265.000000
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250805       lc2509  09:00:01             1    68920.0  245.000000
# 1         20250805       lc2509  09:00:02             1    68840.0  251.666667
# 2         20250805       lc2509  09:00:03             1    68880.0  251.666667
# 3         20250805       lc2509  09:00:04             1    68940.0  253.333333
# 4         20250805       lc2509  09:00:05             1    68960.0  255.000000
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250805       lc2509  14:59:55             1    67700.0  345.000000
# 14396     20250805       lc2509  14:59:56             1    67680.0  345.000000
# 14397     20250805       lc2509  14:59:57             1    67680.0  345.000000
# 14398     20250805       lc2509  14:59:58             1    67680.0  345.000000
# 14399     20250805       lc2509  14:59:59             1    67660.0  345.000000
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250806       lc2511  10:00:01             1    68380.0  250.000000
# 1         20250806       lc2511  10:00:02             1    68380.0  251.666667
# 2         20250806       lc2511  10:00:03             1    68360.0  251.666667
# 3         20250806       lc2511  10:00:04             1    68340.0  253.333333
# 4         20250806       lc2511  10:00:05             1    68360.0  253.333333
# ...            ...          ...       ...           ...        ...         ...
# 10795     20250806       lc2511  14:59:55             1    69600.0  320.000000
# 10796     20250806       lc2511  14:59:56             1    69620.0  320.000000
# 10797     20250806       lc2511  14:59:57             1    69600.0  320.000000
# 10798     20250806       lc2511  14:59:58             1    69600.0  320.000000
# 10799     20250806       lc2511  14:59:59             1    69620.0  320.000000
#
# [10800 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250807       lc2511  09:00:01             1    69740.0  306.666667
# 1         20250807       lc2511  09:00:02             1    69780.0  310.000000
# 2         20250807       lc2511  09:00:03             1    69740.0  310.000000
# 3         20250807       lc2511  09:00:04             1    69700.0  310.000000
# 4         20250807       lc2511  09:00:05             1    69760.0  310.000000
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250807       lc2511  14:59:55             1    72300.0  376.666667
# 14396     20250807       lc2511  14:59:56             1    72300.0  376.666667
# 14397     20250807       lc2511  14:59:57             1    72300.0  376.666667
# 14398     20250807       lc2511  14:59:58             1    72320.0  376.666667
# 14399     20250807       lc2511  14:59:59             1    72300.0  376.666667
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250808       lc2511  09:00:01             1    72860.0  401.666667
# 1         20250808       lc2511  09:00:02             1    72920.0  401.666667
# 2         20250808       lc2511  09:00:03             1    72920.0  401.666667
# 3         20250808       lc2511  09:00:04             1    72800.0  401.666667
# 4         20250808       lc2511  09:00:05             1    72780.0  401.666667
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250808       lc2511  14:59:55             1    76840.0  393.333333
# 14396     20250808       lc2511  14:59:56             1    76820.0  393.333333
# 14397     20250808       lc2511  14:59:57             1    76820.0  393.333333
# 14398     20250808       lc2511  14:59:58             1    76880.0  393.333333
# 14399     20250808       lc2511  14:59:59             1    76900.0  393.333333
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice    ATR
# 0         20250811       lc2511  09:00:01             1    81000.0  685.0
# 1         20250811       lc2511  09:00:02             1    81000.0  685.0
# 2         20250811       lc2511  09:00:03             1    81000.0  685.0
# 3         20250811       lc2511  09:00:04             1    81000.0  685.0
# 4         20250811       lc2511  09:00:05             1    81000.0  685.0
# ...            ...          ...       ...           ...        ...    ...
# 14395     20250811       lc2511  14:59:55             1    81000.0    0.0
# 14396     20250811       lc2511  14:59:56             1    81000.0    0.0
# 14397     20250811       lc2511  14:59:57             1    81000.0    0.0
# 14398     20250811       lc2511  14:59:58             1    81000.0    0.0
# 14399     20250811       lc2511  14:59:59             1    81000.0    0.0
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice  \
# 0         20250812       lc2511  09:00:01             1    87340.0
# 1         20250812       lc2511  09:00:02             1    87440.0
# 2         20250812       lc2511  09:00:03             1    87840.0
# 3         20250812       lc2511  09:00:04             1    88520.0
# 4         20250812       lc2511  09:00:05             1    88560.0
# ...            ...          ...       ...           ...        ...
# 14395     20250812       lc2511  14:59:55             1    82580.0
# 14396     20250812       lc2511  14:59:56             1    82600.0
# 14397     20250812       lc2511  14:59:57             1    82520.0
# 14398     20250812       lc2511  14:59:58             1    82520.0
# 14399     20250812       lc2511  14:59:59             1    82500.0
#
#                ATR
# 0       548.333333
# 1       548.333333
# 2       570.000000
# 3       626.666667
# 4       630.000000
# ...            ...
# 14395  1098.333333
# 14396  1098.333333
# 14397  1098.333333
# 14398  1098.333333
# 14399  1098.333333
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice  \
# 0         20250813       lc2511  09:00:01             1    83260.0
# 1         20250813       lc2511  09:00:02             1    83420.0
# 2         20250813       lc2511  09:00:03             1    83500.0
# 3         20250813       lc2511  09:00:04             1    83540.0
# 4         20250813       lc2511  09:00:05             1    83360.0
# ...            ...          ...       ...           ...        ...
# 14395     20250813       lc2511  14:59:55             1    85100.0
# 14396     20250813       lc2511  14:59:56             1    85100.0
# 14397     20250813       lc2511  14:59:57             1    85100.0
# 14398     20250813       lc2511  14:59:58             1    85080.0
# 14399     20250813       lc2511  14:59:59             1    85100.0
#
#                ATR
# 0      1113.333333
# 1      1126.666667
# 2      1133.333333
# 3      1138.333333
# 4      1138.333333
# ...            ...
# 14395   776.666667
# 14396   776.666667
# 14397   776.666667
# 14398   776.666667
# 14399   776.666667
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250814       lc2511  09:00:01             1    85500.0  775.000000
# 1         20250814       lc2511  09:00:02             1    85400.0  775.000000
# 2         20250814       lc2511  09:00:03             1    85300.0  775.000000
# 3         20250814       lc2511  09:00:04             1    85280.0  775.000000
# 4         20250814       lc2511  09:00:05             1    85340.0  775.000000
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250814       lc2511  14:59:55             1    85180.0  551.666667
# 14396     20250814       lc2511  14:59:56             1    85220.0  551.666667
# 14397     20250814       lc2511  14:59:57             1    85220.0  551.666667
# 14398     20250814       lc2511  14:59:58             1    85260.0  551.666667
# 14399     20250814       lc2511  14:59:59             1    85240.0  551.666667
#
# [14400 rows x 6 columns]
#       trading_date InstrumentID        ts  session_part  LastPrice         ATR
# 0         20250815       lc2511  09:00:01             1    85780.0  565.000000
# 1         20250815       lc2511  09:00:02             1    85920.0  576.666667
# 2         20250815       lc2511  09:00:03             1    85960.0  580.000000
# 3         20250815       lc2511  09:00:04             1    85920.0  580.000000
# 4         20250815       lc2511  09:00:05             1    85760.0  580.000000
# ...            ...          ...       ...           ...        ...         ...
# 14395     20250815       lc2511  14:59:55             1    86960.0  433.333333
# 14396     20250815       lc2511  14:59:56             1    86960.0  433.333333
# 14397     20250815       lc2511  14:59:57             1    86980.0  433.333333
# 14398     20250815       lc2511  14:59:58             1    86960.0  433.333333
# 14399     20250815       lc2511  14:59:59             1    86940.0  433.333333
#
# [14400 rows x 6 columns]
#         trading_date InstrumentID        ts  session_part  LastPrice  \
# 0           20230721       lc2401  10:00:01             1   220550.0
# 1           20230721       lc2401  10:00:02             1   220550.0
# 2           20230721       lc2401  10:00:03             1   220450.0
# 3           20230721       lc2401  10:00:04             1   220650.0
# 4           20230721       lc2401  10:00:05             1   220650.0
# ...              ...          ...       ...           ...        ...
# 7214394     20250815       lc2511  14:59:55             1    86960.0
# 7214395     20250815       lc2511  14:59:56             1    86960.0
# 7214396     20250815       lc2511  14:59:57             1    86980.0
# 7214397     20250815       lc2511  14:59:58             1    86960.0
# 7214398     20250815       lc2511  14:59:59             1    86940.0
#
#                  ATR
# 0        3116.666667
# 1        3116.666667
# 2        3116.666667
# 3        3125.000000
# 4        3125.000000
# ...              ...
# 7214394   433.333333
# 7214395   433.333333
# 7214396   433.333333
# 7214397   433.333333
# 7214398   433.333333
#
# [7214399 rows x 6 columns]

# %%
result.to_parquet(f'C:/Users/CYWY2K/HKUST/STUDY/summer/MAFS6100T/week5/processed_data/2023-2025/{comd}/{comd}_atr_1s_.parquet')
